# %% [markdown]
# # Imports

# %%
import ipynb.fs.full.Test as data
# Out:
# /home/leandro/Documentos/Mestrado/ACOPResults/acopEnv/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
#   9%|▉         | 4/43 [00:00<00:01, 38.83it/s]
# [200, 179, 219, 199, 209, 219, 1239, 1238, 976, 179, 809, 919, 219]
# 2 chs: 200 entries
# 3 chs: 179 entries
# 4 chs: 219 entries
# 5 chs: 199 entries
# 6 chs: 209 entries
# 7 chs: 219 entries
# 8 chs: 1239 entries
# 9 chs: 1238 entries
# 10 chs: 976 entries
# 15 chs: 179 entries
# 20 chs: 809 entries
# 30 chs: 919 entries
# 40 chs: 219 entries
#  77%|███████▋  | 33/43 [00:07<00:03,  3.33it/s]
# RANSACRegressor model failed to execute
# ...

# %% [markdown]
# # Sorting the dataset

# %%
rows, cols, values = data.prepTable(0)
print(rows)
# Out:
# ['BaggingRegressor', 'RandomForestRegressor', 'TransformedTargetRegressor', 'LinearRegression', 'LassoCV', 'GradientBoostingRegressor', 'XGBRegressor', 'ExtraTreesRegressor', 'DecisionTreeRegressor', 'ExtraTreeRegressor', 'HistGradientBoostingRegressor', 'LGBMRegressor', 'GaussianProcessRegressor', 'RidgeCV', 'Ridge', 'ElasticNetCV', 'BayesianRidge', 'MLPRegressor', 'PoissonRegressor', 'SGDRegressor', 'LarsCV', 'LassoLarsCV', 'Lars', 'LassoLarsIC', 'OrthogonalMatchingPursuitCV', 'HuberRegressor', 'LinearSVR', 'NuSVR', 'SVR', 'KNeighborsRegressor', 'AdaBoostRegressor', 'OrthogonalMatchingPursuit', 'TweedieRegressor', 'GeneralizedLinearRegressor', 'ElasticNet', 'Lasso', 'LassoLars', 'DummyRegressor', 'PassiveAggressiveRegressor', 'KernelRidge']

# %% [markdown]
# # Data proccessing

# %% [markdown]
# # Model setup

# %% [markdown]
# # Draw table
